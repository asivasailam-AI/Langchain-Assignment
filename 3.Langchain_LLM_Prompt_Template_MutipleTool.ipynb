# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.tools import Tool
from langchain_openai import ChatOpenAI

# 🔐 Load API keys
load_dotenv(dotenv_path=".env")

# 🔸 Initialize the LLM
llm = ChatOpenAI(
    model="gpt-4.1-mini",
    temperature=0,
    
)


# ==========================================================
# ✅ Tool 1: Simple QA Tool
# ==========================================================

qa_prompt = ChatPromptTemplate.from_template(
    "Answer clearly: {question}"
)

qa_chain = qa_prompt | llm

qa_tool = Tool(
    name="Simple QA",
    func=lambda question: qa_chain.invoke(
        {"question": question}
    ).content,
    description="Answer factual questions clearly"
)

# ==========================================================
# ✅ Tool 2: Summarizer Tool
# ==========================================================

summary_prompt = ChatPromptTemplate.from_template(
    "Summarize the following text:\n\n{text}"
)

summary_chain = summary_prompt | llm

summary_tool = Tool(
    name="Summarizer",
    func=lambda text: summary_chain.invoke(
        {"text": text}
    ).content,
    description="Summarizes input text"
)

# ==========================================================
# 🔧 Tool Usage Examples
# ==========================================================

qa_query = "What is LangGraph in LangChain?"

summary_text = """
LangGraph is a library built on top of LangChain that helps developers create
stateful, multi-step agents as graphs. Each node represents a step like calling
an LLM or a tool. It's ideal for advanced AI workflows.
"""

# ==========================================================
# 🚀 Run Tools
# ==========================================================

print("\n🧠 Simple QA Tool Output:\n")
print(qa_tool.invoke(qa_query))

print("\n📝 Summarizer Tool Output:\n")
print(summary_tool.invoke(summary_text))
# Out:
# 🧠 Simple QA Tool Output:
#
# LangGraph in LangChain is a component or concept that represents a graph-based structure to manage and orchestrate the flow of data and operations between different language model chains or agents. It allows users to define complex workflows where multiple chains or tools interact, enabling more sophisticated and interconnected language model applications. Essentially, LangGraph helps in visualizing and controlling how various parts of a LangChain application communicate and work together.
#
# 📝 Summarizer Tool Output:
#
# LangGraph is a library based on LangChain that enables developers to build stateful, multi-step agents using graph structures, where each node represents a step such as calling an LLM or a tool, making it suitable for advanced AI workflows.
